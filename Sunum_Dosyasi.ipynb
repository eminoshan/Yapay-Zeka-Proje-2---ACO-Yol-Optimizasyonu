# %% [markdown]
# # 🚌 Yapay Zeka Proje 2 - ACO Yol Optimizasyonu
#
# ---
#
# ## 👤 Öğrenci Bilgileri
#
# | Bilgi | Değer |
# |-------|-------|
# | **Adı** | Muhammed Emin |
# | **Soyadı** | Oshan |
# | **Okul Numarası** | 2212729007 |
# | **Üniversite** | Isparta Uygulamalı Bilimler Üniversitesi (SDÜ) |
# | **Senaryo** | 7 - Kampüs Ring Seferi Optimizasyonu |
# | **GitHub Repository** | [aco_yol_optimizasyonu](https://github.com/eminoshan/Yapay-Zeka-Proje-2---ACO-Yol-Optimizasyonu/upload/main() |
#
#
# ---
#
# ## 📋 Proje Özeti
#
# **Senaryo 7:** Isparta Uygulamalı Bilimler Üniversitesi (SDÜ) kampüsü içinde, otobüs seferinin 10 durakta durarak **en kısa sürede tur atması** için Karınca Kolonisi Algoritması (ACO) kullanılmıştır.
#
# ### 🎯 Ana Hedefler
# - ✅ ACO Algoritması implementasyonu
# - ✅ TSP (Travelling Salesman Problem) çözümü
# - ✅ Google Maps API entegrasyonu
# - ✅ Modüler kod yapısı
# - ✅ İnteraktif Streamlit arayüzü
# - ✅ Veri visualizasyonu

# %% [markdown]
# ---
#
# ## 🚀 Nasıl Çalıştırılır?
#
# ### 1. Gerekli Paketleri Yükle

# %%
# Terminal'de çalıştır:
# pip install -r requirements.txt

# %% [markdown]
# ### 2. Streamlit Uygulamasını Başlat

# %%
# Terminal'de çalıştır:
# streamlit run main.py

# Tarayıcı otomatik olarak açılacak:
# http://localhost:8501

# %% [markdown]
# ---
#
# ## ⚙️ Kullanılan Teknolojiler
#
# | Teknoloji | Kullanım |
# |-----------|----------|
# | **Python 3.9+** | Programlama dili |
# | **Streamlit** | Web arayüzü |
# | **NumPy** | Sayısal hesaplamalar |
# | **Pandas** | Veri işleme |
# | **Matplotlib** | Grafik oluşturma |
# | **Google Maps API** | Gerçek mesafeler |
# | **Git** | Sürüm kontrolü |
#
# ---
#
# ## 🐜 Karınca Kolonisi Algoritması (ACO)
#
# ### Algoritma İşleyişi
#
# 1. **İniciyalizasyon:** Feromon matrisi başlatılır
# 2. **Her İterasyon:**
#    - Her karınca tüm düğümleri ziyaret eder
#    - Seçim: `(Feromon^α) × (1/Mesafe^β)`
#    - Rulet Tekerleği seçimi
# 3. **Feromon Güncelleme:** En iyi çözümü bulanlar feromon bırakır
# 4. **Buharlaşma:** Eski feromonlar azalır
# 5. **Sonlandırma:** Belirtilen iterasyonda biter
#
# ### Parametreler
#
# - **n_ants:** 30 (Karınca sayısı)
# - **n_iterations:** 100 (İterasyon sayısı)
# - **alpha:** 1.0 (Feromon ağırlığı)
# - **beta:** 2.0 (Mesafe ağırlığı)
# - **evaporation:** 0.3 (Feromon buharlaşma)
#
# ---
#
# ## 📊 Beklenen Sonuçlar
#
# - **Optimum Mesafe:** ~8-9 km
# - **Ziyaret Edilen Durak:** 10
# - **Yakınsama:** 100 iterasyonda optimal çözüme yaklaşma
# - **Rota Haritası:** Duraklarla birlikte visualize edilmiş rota
#
# ---
#
# ## 📚 Referanslar
#
# 1. Dorigo, M., & Stützle, T. (2004). Ant Colony Optimization.
# 2. Wikipedia - Travelling Salesman Problem
# 3. Google Maps API Documentation
# 4. Streamlit Official Documentation
#
# ---
#
# ## 🔗 Linkler
#
# - **GitHub Repository:** [aco_yol_optimizasyonu](https://github.com/kullanici_adi/aco_yol_optimizasyonu)
# - **Streamlit Dokümantasyonu:** [streamlit.io](https://streamlit.io)
# - **ACO Algoritması:** [Wikipedia](https://en.wikipedia.org/wiki/Ant_colony_optimization)
#
# ---
#
# **Proje Tamamlanma Tarihi:** Aralık 2025
